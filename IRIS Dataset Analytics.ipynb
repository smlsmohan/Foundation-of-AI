# %%
import pandas as pds

#loading Employee CSV 
column_names = ["sepal_length_in_cm","sepal_width_in_cm","petal_length_in_cm","petal_width_in_cm","class"]

data = pds.read_csv('C:/Users/HP/Downloads/Foundations of AI/iris.data',names=column_names)

#Displaying Summary
data.head()
# Out:
#    sepal_length_in_cm  sepal_width_in_cm  petal_length_in_cm  \
# 0                 5.1                3.5                 1.4
# 1                 4.9                3.0                 1.4
# 2                 4.7                3.2                 1.3
# 3                 4.6                3.1                 1.5
# 4                 5.0                3.6                 1.4
#
#    petal_width_in_cm        class
# 0                0.2  Iris-setosa
# 1                0.2  Iris-setosa
# 2                0.2  Iris-setosa
# 3                0.2  Iris-setosa
# 4                0.2  Iris-setosa

# %%
#Features of IRIS Dataset
list(data.columns[0:-1])
# Out:
# ['sepal_length_in_cm',
#  'sepal_width_in_cm',
#  'petal_length_in_cm',
#  'petal_width_in_cm']

# %%
# Target class and its unique values
print("Target class in the IRIS dataset:")
print(data['class'].unique())
# Out:
# Target class in the IRIS dataset:
# ['Iris-setosa' 'Iris-versicolor' 'Iris-virginica']

# %%
# Compute min, max, standard deviation, and median
data_dispersion = data.describe().loc[['min', 'max', 'std', '50%']]
print(data_dispersion)
# Out:
#      sepal_length_in_cm  sepal_width_in_cm  petal_length_in_cm  \
# min            4.300000           2.000000             1.00000
# max            7.900000           4.400000             6.90000
# std            0.828066           0.433594             1.76442
# 50%            5.800000           3.000000             4.35000
#
#      petal_width_in_cm
# min           0.100000
# max           2.500000
# std           0.763161
# 50%           1.300000

# %%
# Computing data dispersion features
numeric_columns = ["sepal_length_in_cm","sepal_width_in_cm","petal_length_in_cm","petal_width_in_cm"]
    
min_values = data[numeric_columns].min()
max_values = data[numeric_columns].max()
std_values = data[numeric_columns].std()
median_values = data[numeric_columns].median()

print("Minimum values:\n", min_values)
print("Maximum values:\n", max_values)
print("Standard deviation:\n", std_values)
print("Median values:\n", median_values)
# Out:
# Minimum values:
#  sepal_length_in_cm    4.3
# sepal_width_in_cm     2.0
# petal_length_in_cm    1.0
# petal_width_in_cm     0.1
# dtype: float64
# Maximum values:
#  sepal_length_in_cm    7.9
# sepal_width_in_cm     4.4
# petal_length_in_cm    6.9
# petal_width_in_cm     2.5
# dtype: float64
# Standard deviation:
#  sepal_length_in_cm    0.828066
# sepal_width_in_cm     0.433594
# petal_length_in_cm    1.764420
# petal_width_in_cm     0.763161
# dtype: float64
# Median values:
#  sepal_length_in_cm    5.80
# sepal_width_in_cm     3.00
# petal_length_in_cm    4.35
# petal_width_in_cm     1.30
# dtype: float64

# %%
#Histogram
import matplotlib.pyplot as plt

data.hist(figsize=(10, 6), bins=20, color='skyblue', edgecolor='black')
plt.suptitle("Histogram of IRIS Dataset Features")
plt.show()

# %%
#boxplot
import seaborn as sns
plt.figure(figsize=(8, 6))
sns.boxplot(data=data)
plt.title("Boxplot of IRIS Features")
plt.show()

# %%
# Scatter plot matrix
import seaborn as sns
import matplotlib.pyplot as plt
sns.pairplot(data, hue='class')
plt.suptitle('Scatter Plot Matrix of Iris Dataset Features')
plt.show()
